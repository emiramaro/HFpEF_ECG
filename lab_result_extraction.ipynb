# %%
import numpy as np
import pandas as pd

# %%
# Loading lab table
lab_df = pd.read_csv("hosp/labevents.csv.gz")

# %%
# Loading ICU stays table
icu_pt_df = pd.read_csv("icu/icustays.csv.gz")

# %%
# ICU stays table
icu_pt_df.head()
# Out:
#    subject_id   hadm_id   stay_id  \
# 0    10000032  29079034  39553978
# 1    10000980  26913865  39765666
# 2    10001217  24597018  37067082
# 3    10001217  27703517  34592300
# 4    10001725  25563031  31205490
#
#                                      first_careunit  \
# 0                Medical Intensive Care Unit (MICU)
# 1                Medical Intensive Care Unit (MICU)
# 2               Surgical Intensive Care Unit (SICU)
# 3               Surgical Intensive Care Unit (SICU)
# 4  Medical/Surgical Intensive Care Unit (MICU/SICU)
#
#                                       last_careunit               intime  \
# 0                Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2               Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 3               Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# ...

# %%
# Lab table
lab_df.head()
# Out:
#    labevent_id  subject_id  hadm_id  specimen_id  itemid order_provider_id  \
# 0            1    10000032      NaN     45421181   51237            P28Z0X
# 1            2    10000032      NaN     45421181   51274            P28Z0X
# 2            3    10000032      NaN     52958335   50853            P28Z0X
# 3            4    10000032      NaN     52958335   50861            P28Z0X
# 4            5    10000032      NaN     52958335   50862            P28Z0X
#
#              charttime            storetime value  valuenum valueuom  \
# 0  2180-03-23 11:51:00  2180-03-23 15:15:00   1.4       1.4      NaN
# 1  2180-03-23 11:51:00  2180-03-23 15:15:00   ___      15.1      sec
# 2  2180-03-23 11:51:00  2180-03-25 11:06:00   ___      15.0    ng/mL
# 3  2180-03-23 11:51:00  2180-03-23 16:40:00   102     102.0     IU/L
# 4  2180-03-23 11:51:00  2180-03-23 16:40:00   3.3       3.3     g/dL
#
#    ref_range_lower  ref_range_upper      flag priority  \
# ...

# %%
# Loading and displaying item id within lab table
lab_id = pd.read_csv('hosp/d_labitems.csv.gz')
lab_id.head()
# Out:
#    itemid                                label  fluid   category
# 0   50801           Alveolar-arterial Gradient  Blood  Blood Gas
# 1   50802                          Base Excess  Blood  Blood Gas
# 2   50803  Calculated Bicarbonate, Whole Blood  Blood  Blood Gas
# 3   50804                 Calculated Total CO2  Blood  Blood Gas
# 4   50805                    Carboxyhemoglobin  Blood  Blood Gas

# %%
# Check which glucose we should use --> itemid: 50931 (mapped to LOINC code 2345-7)
lab_id[lab_id['label'].str.contains("Glucose", na=False)]
# Out:
#       itemid                 label                fluid    category
# 7      50809               Glucose                Blood   Blood Gas
# 40     50842      Glucose, Ascites              Ascites   Chemistry
# 129    50931               Glucose                Blood   Chemistry
# 210    51022  Glucose, Joint Fluid          Joint Fluid   Chemistry
# 222    51034   Glucose, Body Fluid     Other Body Fluid   Chemistry
# 241    51053      Glucose, Pleural              Pleural   Chemistry
# 272    51084        Glucose, Urine                Urine   Chemistry
# 638    51478               Glucose                Urine  Hematology
# 908    51790          Glucose, CSF  Cerebrospinal Fluid   Chemistry
# 1034   51941        Glucose, Stool                Stool   Chemistry
# 1074   51981               Glucose                Urine   Chemistry
# 1120   52027  Glucose, Whole Blood                Blood   Blood Gas
# 1528   52569               Glucose                Blood   Chemistry

# %%
lab_id[lab_id['itemid']==51478]
# Out:
#      itemid    label  fluid    category
# 638   51478  Glucose  Urine  Hematology

# %%
# Check glucose (blood, chemistry, 50931)
lab_df[lab_df['itemid']==50931].head()
# Out:
#      labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 59            60    10000032         NaN     73913913   50931
# 103          104    10000032         NaN     43430170   50931
# 150          151    10000032  22595853.0     93044861   50931
# 172          173    10000032         NaN     41498752   50931
# 185          186    10000032         NaN     86302346   50931
#
#     order_provider_id            charttime            storetime value  \
# 59             P28Z0X  2180-03-23 11:51:00  2180-03-23 15:56:00   ___
# 103               NaN  2180-05-06 22:25:00  2180-05-06 23:16:00   ___
# 150               NaN  2180-05-07 05:05:00  2180-05-07 07:03:00   ___
# 172            P28Z0X  2180-06-03 12:00:00  2180-06-03 13:04:00   ___
# 185            P260SK  2180-06-03 12:00:00  2180-06-03 13:04:00   ___
#
#      valuenum valueuom  ref_range_lower  ref_range_upper      flag priority  \
# 59       95.0    mg/dL             70.0            100.0       NaN  ROUTINE
# ...

# %%
# Check glucose (blood, chemistry, 52569)
lab_df[lab_df['itemid']==52569].head()
# Out:
#         labevent_id  subject_id  hadm_id  specimen_id  itemid  \
# 391367       391898    10034253      NaN     64602824   52569
# 391388       391919    10034253      NaN     88635316   52569
# 517119       517819    10046097      NaN     16230427   52569
# 576779       577617    10049902      NaN     75742106   52569
# 952753       954083    10089199      NaN     42403542   52569
#
#        order_provider_id            charttime            storetime value  \
# 391367            P40IUG  2151-07-29 12:50:00  2151-07-29 13:06:00   104
# 391388            P31PEN  2151-09-30 13:24:00  2151-09-30 13:37:00    97
# 517119            P056IR  2186-11-05 14:35:00  2186-11-05 14:38:00   106
# 576779            P59ABV  2149-10-28 14:48:00  2149-10-28 14:56:00    97
# 952753            P32KL8  2123-10-12 13:50:00  2123-10-12 13:53:00    87
#
#         valuenum valueuom  ref_range_lower  ref_range_upper      flag  \
# 391367     104.0    mg/dL             70.0            100.0  abnormal
# ...

# %%
# %time

# HDL: 50904, total cholesterol : 50907, glucose : 51478
hdl_chol_glu_lab = lab_df[lab_df["itemid"].isin([50904,50907,50931])]
hdl_chol_glu_lab.head()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
#      labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 15            16    10000032         NaN     52958335   50904
# 17            18    10000032         NaN     52958335   50907
# 59            60    10000032         NaN     73913913   50931
# 103          104    10000032         NaN     43430170   50931
# 150          151    10000032  22595853.0     93044861   50931
#
#     order_provider_id            charttime            storetime value  \
# 15             P28Z0X  2180-03-23 11:51:00  2180-03-23 16:40:00    52
# 17             P28Z0X  2180-03-23 11:51:00  2180-03-23 16:40:00   202
# 59             P28Z0X  2180-03-23 11:51:00  2180-03-23 15:56:00   ___
# 103               NaN  2180-05-06 22:25:00  2180-05-06 23:16:00   ___
# 150               NaN  2180-05-07 05:05:00  2180-05-07 07:03:00   ___
#
#      valuenum valueuom  ref_range_lower  ref_range_upper      flag priority  \
# ...

# %%
hdl_chol_glu_lab.shape
# Out:
# (3244066, 16)

# %%
missing_counts = hdl_chol_glu_lab["value"].isna().groupby(hdl_chol_glu_lab["itemid"]).sum()
missing_counts
# Out:
# itemid
# 50904    346
# 50907     29
# 50931    364
# Name: value, dtype: int64
